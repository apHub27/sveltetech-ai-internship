# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 131 (delta 0), reused 0 (delta 0), pack-reused 129 (from 2)
# Receiving objects: 100% (131/131), 1.13 MiB | 3.64 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
# !pip install ninja -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 407.4 kB/s eta 0:00:00

# %%
import torch
print("GPU available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# GPU available: True
# GPU name: Tesla T4

# %%
# %cd /content/stylegan2-ada-pytorch
# !ls
# Out:
# /content/stylegan2-ada-pytorch
# calc_metrics.py  docker_run.sh	LICENSE.txt   style_mixing.py
# dataset_tool.py  docs		metrics       torch_utils
# dnnlib		 generate.py	projector.py  training
# Dockerfile	 legacy.py	README.md     train.py

# %%
# !python generate.py --outdir=out --seeds=0-4 --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl

# %%
from PIL import Image
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 5, figsize=(20, 4))
for i in range(5):
    img = Image.open(f'out/seed{i:04d}.png')
    axes[i].imshow(img)
    axes[i].axis('off')
plt.suptitle("StyleGAN2 - Generated Faces (Pretrained on FFHQ)")
plt.show()
