# %% [markdown]
# <a href="https://colab.research.google.com/github/apHub27/sveltetech-ai-internship/blob/main/04_supervised_vs_unsupervised_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data = np.array([45,np.nan,48,52,900])
cleaned_data =np.nanmean(data)
print("cleaned data:",cleaned_data)
print("-"*40)
no_outlier_data = np.nanmedian(data)
print("median after outlier removal:",no_outlier_data)

#removing the outlier and blank data from the main data
cleaning_data = np.array(data)<100
cleaned_data = data[cleaning_data]
print("cleaned data:",cleaned_data)
# Out:
# cleaned data: 261.25
# ----------------------------------------
# median after outlier removal: 50.0
# cleaned data: [45. 48. 52.]

# %%
import numpy as np

# 2 Questions, 2 matching Answers
supervised_questions = np.array([[1, 40],
                                 [2, 50]])

supervised_answers = np.array([0, 1]) # Row 1 -> Stop (0), Row 2 -> Go (1)

print("Clean Questions:\n", supervised_questions)
print("Clean Answers:", supervised_answers)

raw_documents_X = np.array([[1000,2],[1200,1],[15,50]])
print("Raw Matrix to Cluster (X):\n", raw_documents_X)
# Out:
# Clean Questions:
#  [[ 1 40]
#  [ 2 50]]
# Clean Answers: [0 1]
# Raw Matrix to Cluster (X):
#  [[1000    2]
#  [1200    1]
#  [  15   50]]
